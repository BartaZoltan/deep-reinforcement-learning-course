# %% [markdown]
# ![Logo](https://raw.githubusercontent.com/BartaZoltan/deep-reinforcement-learning-course/main/notebooks/shared_assets/logo.png)
#
# **Developers:** <Developer Name(s)>
# **Date:** <YYYY-MM-DD>
# **Version:** 2025-26/2
#
# [<img src="https://colab.research.google.com/assets/colab-badge.svg">](<COLAB_NOTEBOOK_URL>)
#
# # Practice <N>: <Session Title>
#
# ## Summary
#
# Short overview of the practical topic.
#
# Content outline:
# - topic block 1,
# - topic block 2,
# - topic block 3,
# - topic block 4.

# %% [markdown]
# ## Introduction
#
# Main conceptual introduction for the session.
#
# Use inline citations when needed, e.g. {cite}`sutton2018`.

# %% [markdown]
# ## Setup
#
# Brief setup notes for the notebook environment and reproducibility.

# %%
import numpy as np
import random

SEED = 42
np.random.seed(SEED)
random.seed(SEED)

try:
    import torch
    torch.manual_seed(SEED)
except Exception:
    pass

# %% [markdown]
# ## Task 1: <Task Name>
#
# Task description and expected output.

# %%
# TODO: Implement Task 1
pass

# %% [markdown]
# ## Task 2: <Task Name>
#
# Task description and expected output.

# %%
# TODO: Implement Task 2
pass

# %% [markdown]
# ## Experiments
#
# Describe experiment settings and comparison criteria.

# %%
# TODO: Run experiments and plots
pass

# %% [markdown]
# ## Conclusions
#
# Short takeaway points.

# %% [markdown]
# # References
#
# ```{bibliography}
# ```
