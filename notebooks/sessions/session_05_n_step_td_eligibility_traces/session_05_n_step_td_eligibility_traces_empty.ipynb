# %% [markdown]
# ![Logo](https://github.com/BartaZoltan/deep-reinforcement-learning-course/blob/main/website/assets/logo.png?raw=1)
#
# Made by **Zoltán Barta**
#
# [<img src="https://colab.research.google.com/assets/colab-badge.svg">](https://colab.research.google.com/github/BartaZoltan/deep-reinforcement-learning-course/blob/main/notebooks/sessions/session_05_n_step_td_eligibility_traces/session_05_n_step_td_eligibility_traces_empty.ipynb)
#
# # Practical 5: n-step Returns and Eligibility Traces

# %% [markdown]
# ## Session Overview
#
# This notebook will contain the practical material for this session.
#
# Planned sections:
# - Theory recap
# - Implementation tasks
# - Experiments and analysis
# - Reflection questions

# %%
# TODO: add imports and environment setup for this session
# import numpy as np
# import torch
# import gymnasium as gym

# %% [markdown]
# ## Exercises
#
# Add the step-by-step practical tasks here.
